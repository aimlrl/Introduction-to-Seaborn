# %%
import pandas as pd

import seaborn as sns

# %%
banking_data = pd.read_csv("bank_marketing.csv")

# %%
banking_data
# Out:
#       Unnamed: 0  age            job   marital  education default  balance  \
# 0              0   41       services   married    unknown      no       88
# 1              1   56     technician   married  secondary      no     1938
# 2              2   30       services    single  secondary      no      245
# 3              3   34     management    single   tertiary      no     1396
# 4              4   29     technician    single  secondary      no      -13
# 5              5   26     unemployed    single  secondary      no      632
# 6              6   59        retired   married    primary      no     2074
# 7              7   46     management   married   tertiary      no        3
# 8              8   61        retired   married  secondary      no      569
# 9              9   35    blue-collar  divorced  secondary      no      336
# 10            10   51     unemployed   married  secondary      no     1416
# ...

# %%
banking_data.columns
# Out:
# Index(['Unnamed: 0', 'age', 'job', 'marital', 'education', 'default',
#        'balance', 'housing', 'loan', 'contact', 'day', 'month', 'duration',
#        'campaign', 'pdays', 'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %%
banking_data.drop([banking_data.columns[0]],axis=1,inplace=True)

# %%
banking_data.head()
# Out:
#    age         job  marital  education default  balance housing loan  \
# 0   41    services  married    unknown      no       88     yes   no
# 1   56  technician  married  secondary      no     1938      no  yes
# 2   30    services   single  secondary      no      245      no  yes
# 3   34  management   single   tertiary      no     1396     yes   no
# 4   29  technician   single  secondary      no      -13     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome deposit
# 0  cellular   11   may       105         1    336         2  failure      no
# 1  cellular   26   feb       229         1    192         4  success     yes
# 2  cellular    8   jul       187         2     -1         0  unknown      no
# 3  cellular   17   jul       630         1     -1         0  unknown      no
# 4  cellular   14   may       512         3     -1         0  unknown      no

# %%
banking_data.shape
# Out:
# (5581, 17)

# %%
banking_data['default'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
import numpy as np

# %%
np.count_nonzero(banking_data['default'] == 'yes')
# Out:
# 84

# %%
banking_data['job'].unique()
# Out:
# array(['services', 'technician', 'management', 'unemployed', 'retired',
#        'blue-collar', 'housemaid', 'admin.', 'entrepreneur', 'student',
#        'self-employed', 'unknown'], dtype=object)

# %%
banking_data['marital'].unique()
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
sns.relplot(x='duration',y='balance',hue='education',col='default',row='job',data=banking_data)

# %%
sns.relplot(x='age',y='balance',hue='default',height=10,data=banking_data)

# %%
sns.relplot(x='duration',y='age',hue='default',data=banking_data)

# %%
sns.relplot(x='job',y='education',hue='default',data=banking_data)
